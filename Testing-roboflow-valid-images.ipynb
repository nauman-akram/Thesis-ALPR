# %%
import requests
import os
import time
import pandas as pd
from pprint import pprint

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Nauman\\Documents\\Masters Project'

# %%
import IPython.display as display
from PIL import Image

def show_image(fname):
    """Show an image in a Jupyter notebook."""
    image = Image.open(fname)
    display.display(image)

# %%
def call_PRAPI(file_path):
    
    with open(file_path, 'rb') as fp:

        response = requests.post(
            'https://api.platerecognizer.com/v1/plate-reader/',
            #data=dict(regions=regions),  # Optional
            files=dict(upload=fp),
            headers={'Authorization': 'Token 5ea9aaf15a07f768e4959ece52955592138fb925'})
        result = response.json()
    return result

# %%
dataset_path = os.path.join(os.getcwd(),'dataset\\valid')
dataset_path
# Out:
# 'C:\\Users\\Nauman\\Documents\\Masters Project\\dataset\\valid'

# %%
df = pd.read_csv(dataset_path+'\\_annotations.csv')

# %%
df
# Out:
#                                              filename  width  height  \
# 0   00072_jpg.rf.04b4e5649a4b9be614bad3b16b13b645.jpg   1280     720
# 1   Screenshot--312----Copy_png.rf.10ff8ca6e9da749...    958     538
# 2   Screenshot--345-_png.rf.060c20eba6d7449f321c0f...    957     536
# 3   00514_jpg.rf.21661970dfe53bb05e2d9ece983b0729.jpg   1280     720
# 4   vlcsnap-2022-09-21-17h10m32s794_png.rf.12c1dca...   1920    1080
# 5   N100_jpeg.rf.033d00a5dcb90249ea4538010198e6fd.jpg    450     417
# 6   00644_jpg.rf.1bdca5b4a27d3189e2200aa730465b4e.jpg   1280     720
# 7   00656_jpg.rf.6792606384410df57612e34297e48739.jpg   1280     720
# 8   00452_jpg.rf.722fc5335223cf51d9401dff85a93558.jpg   1280     720
# 9   N119_jpeg.rf.11496033ce735564bf415f3e08b73c10.jpg    678     475
# 10  00612_jpg.rf.26d856e26548afc0ebcbb1fed2a75af3.jpg   1280     720
# 11  00624_jpg.rf.46a0bb6276551c65d710c247d419fae6.jpg   1280     720
# 12  N141_jpeg.rf.7bc1766815842b67d74ee266342dba46.jpg    500     416
# ...

# %%
detection = []
for fn in df.filename:
    img_path = dataset_path+'\\'+fn
    #print(img_path)
    #show_image(dataset_path+'\\'+fn)
    response = call_PRAPI(img_path)
    print(response)
    if response['results']:
        lp =  response['results'][0]['plate'] 
        print(lp)
        detection.append( lp)
    else:
        detection.append('not found')

    time.sleep(1.1)
# Out:
# C:\Users\Nauman\Documents\Masters Project\dataset\valid\00072_jpg.rf.04b4e5649a4b9be614bad3b16b13b645.jpg
# {'processing_time': 131.213, 'results': [{'box': {'xmin': 506, 'ymin': 533, 'xmax': 564, 'ymax': 553}, 'plate': 'cav2889', 'region': {'code': 'ua', 'score': 0.163}, 'score': 0.9, 'candidates': [{'score': 0.9, 'plate': 'cav2889'}, {'score': 0.778, 'plate': 'cav28b9'}, {'score': 0.777, 'plate': 'cav2b89'}, {'score': 0.656, 'plate': 'cav2bb9'}], 'dscore': 0.764, 'vehicle': {'score': 0.582, 'type': 'Sedan', 'box': {'xmin': 378, 'ymin': 400, 'xmax': 608, 'ymax': 589}}}], 'filename': '1420_38zQV_00072_jpg.rf.04b4e5649a4b9be614bad3b16b13b645.jpg', 'version': 1, 'camera_id': None, 'timestamp': '2023-07-19T14:20:59.280040Z'}
# cav2889
# C:\Users\Nauman\Documents\Masters Project\dataset\valid\Screenshot--312----Copy_png.rf.10ff8ca6e9da749e178d1da6ccc31157.jpg
# ...

# %%
detection
# Out:
# ['cav2889',
#  'gb7761',
#  'kt0174',
#  'pj5175',
#  'pi2260',
#  'hr26ct4063',
#  'kg1913',
#  'kg1913',
#  'pj5175',
#  'kl7bz99',
#  'kg1913',
#  'kg1913',
#  'hr99extemp6',
#  'dl10ntc0169',
#  '658082',
#  'tn42rs697',
#  'cah0554',
#  'pf1586',
#  'hr26da5443',
#  'kg3332',
#  'hr99bj6662',
#  'kg1913',
#  '658082',
#  'pj5175',
#  '658082',
#  'kl01kl0kl01',
#  'pj5175',
#  'gj07br133',
#  'kl10aw2111',
#  'dl7cn5617',
#  'pj5175',
#  'not found',
#  '658082',
#  'kg1913',
#  'kg1913',
#  'cav2889',
#  'cas5352',
#  'kg1913',
#  'pf1586',
#  '9kkb22']

# %%
df['PR_det'] = detection

# %%
df
# Out:
#                                              filename  width  height  \
# 0   00072_jpg.rf.04b4e5649a4b9be614bad3b16b13b645.jpg   1280     720
# 1   Screenshot--312----Copy_png.rf.10ff8ca6e9da749...    958     538
# 2   Screenshot--345-_png.rf.060c20eba6d7449f321c0f...    957     536
# 3   00514_jpg.rf.21661970dfe53bb05e2d9ece983b0729.jpg   1280     720
# 4   vlcsnap-2022-09-21-17h10m32s794_png.rf.12c1dca...   1920    1080
# 5   N100_jpeg.rf.033d00a5dcb90249ea4538010198e6fd.jpg    450     417
# 6   00644_jpg.rf.1bdca5b4a27d3189e2200aa730465b4e.jpg   1280     720
# 7   00656_jpg.rf.6792606384410df57612e34297e48739.jpg   1280     720
# 8   00452_jpg.rf.722fc5335223cf51d9401dff85a93558.jpg   1280     720
# 9   N119_jpeg.rf.11496033ce735564bf415f3e08b73c10.jpg    678     475
# 10  00612_jpg.rf.26d856e26548afc0ebcbb1fed2a75af3.jpg   1280     720
# 11  00624_jpg.rf.46a0bb6276551c65d710c247d419fae6.jpg   1280     720
# 12  N141_jpeg.rf.7bc1766815842b67d74ee266342dba46.jpg    500     416
# ...

# %%
valid_test = df.loc[:,['filename','LP_num','PR_det']]

# %%
valid_test.to_csv('RF_valid_test_PR.csv')
